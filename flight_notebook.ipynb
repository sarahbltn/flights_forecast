# %% [markdown]
# # Flight Forecast with Google Flights

# %% [markdown]
# `Authors:` Sarah Beltran, Monica Ibarra & Michelle
#
# `Date:` 08/05/2026
#
# ---

# %% [markdown]
# ## Introduction

# %%
import pandas as pd

# %%
df = pd.read_csv('data/avia_par_uk__custom_21385003_linear_2_0.csv')
df.head()
# Out:
#   STRUCTURE            STRUCTURE_ID  \
# 0  dataflow  ESTAT:AVIA_PAR_UK(1.0)
# 1  dataflow  ESTAT:AVIA_PAR_UK(1.0)
# 2  dataflow  ESTAT:AVIA_PAR_UK(1.0)
# 3  dataflow  ESTAT:AVIA_PAR_UK(1.0)
# 4  dataflow  ESTAT:AVIA_PAR_UK(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency unit  \
# 0  Air passenger transport routes between partner...    M        Monthly  PAS
# 1  Air passenger transport routes between partner...    M        Monthly  PAS
# 2  Air passenger transport routes between partner...    M        Monthly  PAS
# 3  Air passenger transport routes between partner...    M        Monthly  PAS
# 4  Air passenger transport routes between partner...    M        Monthly  PAS
#
#   Unit of measure tra_meas Traffic and transport measurement          airp_pr  \
# 0       Passenger  PAS_BRD               Passengers on board  UK_EGAA_UK_EGGW
# 1       Passenger  PAS_BRD               Passengers on board  UK_EGAA_UK_EGGW
# ...

# %%
df = df.drop(columns=[
    "Time",
    "Observation value",
    "OBS_FLAG",
    "Observation status (Flag) V2 structure",
    "CONF_STATUS",
    "Confidentiality status (flag)"
])
df.head()
# Out:
#   STRUCTURE            STRUCTURE_ID  \
# 0  dataflow  ESTAT:AVIA_PAR_UK(1.0)
# 1  dataflow  ESTAT:AVIA_PAR_UK(1.0)
# 2  dataflow  ESTAT:AVIA_PAR_UK(1.0)
# 3  dataflow  ESTAT:AVIA_PAR_UK(1.0)
# 4  dataflow  ESTAT:AVIA_PAR_UK(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency unit  \
# 0  Air passenger transport routes between partner...    M        Monthly  PAS
# 1  Air passenger transport routes between partner...    M        Monthly  PAS
# 2  Air passenger transport routes between partner...    M        Monthly  PAS
# 3  Air passenger transport routes between partner...    M        Monthly  PAS
# 4  Air passenger transport routes between partner...    M        Monthly  PAS
#
#   Unit of measure tra_meas Traffic and transport measurement          airp_pr  \
# 0       Passenger  PAS_BRD               Passengers on board  UK_EGAA_UK_EGGW
# 1       Passenger  PAS_BRD               Passengers on board  UK_EGAA_UK_EGGW
# ...
